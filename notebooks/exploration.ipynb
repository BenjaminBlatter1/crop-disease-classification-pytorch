# %% [markdown]
# # Dataset Exploration
#
# This notebook will be used to:
# - Inspect the dataset structure
# - Visualize sample images
# - Check class distribution
# - Experiment with basic transforms

# %% [markdown]
# Inspect the dataset structure

# %%
from pathlib import Path

train_dir = Path("data/processed/train")
print("Classes:", [d.name for d in train_dir.iterdir() if d.is_dir()])

# %% [markdown]
# Visualize sample images (currently only one image possible)

# %%
from PIL import Image
import matplotlib.pyplot as plt

sample = next(train_dir.rglob("*.jpg"))
img = Image.open(sample)
plt.imshow(img)
plt.axis("off")
